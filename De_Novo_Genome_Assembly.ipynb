# %% [markdown]
# <a href="https://colab.research.google.com/github/gdakshareddybt23/Bioinformatics/blob/main/De_Novo_Genome_Assembly.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !apt-get install fastqc
# !apt-get install velvet
# !wget 'https://zenodo.org/record/582600/files/mutant_R1.fastq'
# !wget 'https://zenodo.org/record/582600/files/mutant_R2.fastq'
import os
from google.colab import files
get_ipython().system("fastqc mutant_R1.fastq")
files.download('mutant_R1_fastqc.html')
get_ipython().system("fastqc mutant_R2.fastq")
files.download('mutant_R2_fastqc.html')
# !mkdir assembly_module
os.chdir('assembly_module')
# !mkdir data
get_ipython().system("velveth ASM_NAME 31 -short -separate -fastq /content/mutant_R1.fastq /content/mutant_R2.fastq")
get_ipython().system("velvetg ASM_NAME")
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# fastqc is already the newest version (0.11.9+dfsg-5).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# velvet is already the newest version (1.2.10+dfsg1-7).
# 0 upgraded, 0 newly installed, 0 to remove and 1 not upgraded.
# --2026-01-06 05:22:41--  https://zenodo.org/record/582600/files/mutant_R1.fastq
# Resolving zenodo.org (zenodo.org)... 137.138.52.235, 188.185.43.153, 188.185.48.75, ...
# Connecting to zenodo.org (zenodo.org)|137.138.52.235|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/582600/files/mutant_R1.fastq [following]
# --2026-01-06 05:22:41--  https://zenodo.org/records/582600/files/mutant_R1.fastq
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4137809 (3.9M) [application/octet-stream]
# Saving to: ‘mutant_R1.fastq’
#
# mutant_R1.fastq     100%[===================>]   3.95M  3.19MB/s    in 1.2s
#
# 2026-01-06 05:22:43 (3.19 MB/s) - ‘mutant_R1.fastq’ saved [4137809/4137809]
#
# --2026-01-06 05:22:43--  https://zenodo.org/record/582600/files/mutant_R2.fastq
# Resolving zenodo.org (zenodo.org)... 137.138.52.235, 188.185.43.153, 188.185.48.75, ...
# Connecting to zenodo.org (zenodo.org)|137.138.52.235|:443... connected.
# HTTP request sent, awaiting response... 301 MOVED PERMANENTLY
# Location: /records/582600/files/mutant_R2.fastq [following]
# --2026-01-06 05:22:43--  https://zenodo.org/records/582600/files/mutant_R2.fastq
# Reusing existing connection to zenodo.org:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 4137809 (3.9M) [application/octet-stream]
# Saving to: ‘mutant_R2.fastq’
#
# mutant_R2.fastq     100%[===================>]   3.95M  1.05MB/s    in 3.7s
#
# 2026-01-06 05:22:48 (1.05 MB/s) - ‘mutant_R2.fastq’ saved [4137809/4137809]
#
# Started analysis of mutant_R1.fastq
# Approx 5% complete for mutant_R1.fastq
# Approx 15% complete for mutant_R1.fastq
# Approx 20% complete for mutant_R1.fastq
# Approx 30% complete for mutant_R1.fastq
# Approx 40% complete for mutant_R1.fastq
# Approx 45% complete for mutant_R1.fastq
# Approx 55% complete for mutant_R1.fastq
# Approx 60% complete for mutant_R1.fastq
# Approx 70% complete for mutant_R1.fastq
# Approx 80% complete for mutant_R1.fastq
# Approx 85% complete for mutant_R1.fastq
# Approx 95% complete for mutant_R1.fastq
# Analysis complete for mutant_R1.fastq
# Started analysis of mutant_R2.fastq
# Approx 5% complete for mutant_R2.fastq
# Approx 15% complete for mutant_R2.fastq
# Approx 20% complete for mutant_R2.fastq
# Approx 30% complete for mutant_R2.fastq
# Approx 40% complete for mutant_R2.fastq
# Approx 45% complete for mutant_R2.fastq
# Approx 55% complete for mutant_R2.fastq
# Approx 60% complete for mutant_R2.fastq
# Approx 70% complete for mutant_R2.fastq
# Approx 80% complete for mutant_R2.fastq
# Approx 85% complete for mutant_R2.fastq
# Approx 95% complete for mutant_R2.fastq
# Analysis complete for mutant_R2.fastq
# [0.000001] Reading FastQ file /content/mutant_R1.fastq;
# [0.055167] 12480 sequences found
# [0.055186] Done
# [0.055227] Reading FastQ file /content/mutant_R2.fastq;
# [0.111712] 12480 sequences found
# [0.111728] Done
# [0.111789] Reading read set file ASM_NAME/Sequences;
# [0.116512] 24960 sequences found
# [0.139931] Done
# [0.139954] 24960 sequences in total.
# [0.140054] Writing into roadmap file ASM_NAME/Roadmaps...
# [0.185702] Inputting sequences...
# [0.185730] Inputting sequence 0 / 24960
# [1.036538]  === Sequences loaded in 0.850838 s
# [1.036579] Done inputting sequences
# [1.036582] Destroying splay table
# [1.047863] Splay table destroyed
# [0.000000] Reading roadmap file ASM_NAME/Roadmaps
# [0.050627] 24960 roadmaps read
# [0.050848] Creating insertion markers
# [0.054673] Ordering insertion markers
# [0.075062] Counting preNodes
# [0.079014] 64223 preNodes counted, creating them now
# [0.191719] Adjusting marker info...
# [0.195632] Connecting preNodes
# [0.232364] Cleaning up memory
# [0.232512] Done creating preGraph
# [0.232520] Concatenation...
# [0.254865] Renumbering preNodes
# [0.254908] Initial preNode count 64223
# [0.257416] Destroyed 37924 preNodes
# [0.257437] Concatenation over!
# [0.257440] Clipping short tips off preGraph
# [0.258932] Concatenation...
# [0.264059] Renumbering preNodes
# [0.264084] Initial preNode count 26299
# [0.265847] Destroyed 3832 preNodes
# [0.265868] Concatenation over!
# [0.265870] 1986 tips cut off
# [0.265872] 22467 nodes left
# [0.265990] Writing into pregraph file ASM_NAME/PreGraph...
# [0.341775] Reading read set file ASM_NAME/Sequences;
# [0.346473] 24960 sequences found
# [0.370725] Done
# [0.423926] Reading pre-graph file ASM_NAME/PreGraph
# [0.424022] Graph has 22467 nodes and 24960 sequences
# [0.452301] Scanning pre-graph file ASM_NAME/PreGraph for k-mers
# [0.457704] 434645 kmers found
# [0.488047] Sorting kmer occurrence table ...
# [0.614960] Sorting done.
# [0.614990] Computing acceleration table...
# [0.658478] Computing offsets...
# [0.661007] Ghost Threading through reads 0 / 24960
# [0.661324]  === Ghost-Threaded in 0.000317 s
# [0.661333] Threading through reads 0 / 24960
# [1.748702]  === Threaded in 1.087368 s
# [1.753741] Correcting graph with cutoff 0.200000
# [1.755366] Determining eligible starting points
# [1.777196] Done listing starting nodes
# [1.777230] Initializing todo lists
# [1.781755] Done with initialization
# [1.781789] Activating arc lookup table
# [1.784236] Done activating arc lookup table
# [1.901149] 10000 / 22467 nodes visited
# [2.020593] 20000 / 22467 nodes visited
# [2.046823] Concatenation...
# [2.047028] Renumbering nodes
# [2.047037] Initial node count 22467
# [2.047106] Removed 22097 null nodes
# [2.047112] Concatenation over!
# [2.047114] Clipping short tips off graph, drastic
# [2.047142] Concatenation...
# [2.047313] Renumbering nodes
# [2.047318] Initial node count 370
# [2.047329] Removed 14 null nodes
# [2.047331] Concatenation over!
# [2.047335] 356 nodes left
# [2.047592] Writing into graph file ASM_NAME/Graph...
# [2.071303] WARNING: NO COVERAGE CUTOFF PROVIDED
# [2.071328] Velvet will probably leave behind many detectable errors
# [2.071331] See manual for instructions on how to set the coverage cutoff parameter
# [2.071334] Removing contigs with coverage < -1.000000...
# [2.071360] Concatenation...
# [2.071382] Renumbering nodes
# [2.071384] Initial node count 356
# [2.071387] Removed 0 null nodes
# [2.071389] Concatenation over!
# [2.071408] Concatenation...
# [2.071426] Renumbering nodes
# [2.071431] Initial node count 356
# [2.071436] Removed 0 null nodes
# [2.071438] Concatenation over!
# [2.071440] Clipping short tips off graph, drastic
# [2.071450] Concatenation...
# [2.071466] Renumbering nodes
# [2.071471] Initial node count 356
# [2.071476] Removed 0 null nodes
# [2.071477] Concatenation over!
# [2.071479] 356 nodes left
# [2.071481] WARNING: NO EXPECTED COVERAGE PROVIDED
# [2.071485] Velvet will be unable to resolve any repeats
# [2.071487] See manual for instructions on how to set the expected coverage parameter
# [2.071489] Concatenation...
# [2.071504] Renumbering nodes
# [2.071510] Initial node count 356
# [2.071513] Removed 0 null nodes
# [2.071519] Concatenation over!
# [2.071524] Removing reference contigs with coverage < -1.000000...
# [2.071545] Concatenation...
# [2.071563] Renumbering nodes
# [2.071568] Initial node count 356
# [2.071694] Removed 0 null nodes
# [2.071705] Concatenation over!
# [2.071936] Writing contigs into ASM_NAME/contigs.fa...
# [2.086812] Writing into stats file ASM_NAME/stats.txt...
# [2.087929] Writing into graph file ASM_NAME/LastGraph...
# Final graph has 356 nodes and n50 of 5029, max 12902, total 184065, using 0/24960 reads
